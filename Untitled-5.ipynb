# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import pandas as pd
import time
import re
import webcolors
# !pip install selenium beautifulsoup4 pandas webcolors
# Out:
# Requirement already satisfied: selenium in c:\users\ruchi\anaconda3\lib\site-packages (4.34.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\ruchi\anaconda3\lib\site-packages (4.12.3)
# Requirement already satisfied: pandas in c:\users\ruchi\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: webcolors in c:\users\ruchi\anaconda3\lib\site-packages (24.11.1)
# Requirement already satisfied: urllib3~=2.5.0 in c:\users\ruchi\anaconda3\lib\site-packages (from urllib3[socks]~=2.5.0->selenium) (2.5.0)
# Requirement already satisfied: trio~=0.30.0 in c:\users\ruchi\anaconda3\lib\site-packages (from selenium) (0.30.0)
# Requirement already satisfied: trio-websocket~=0.12.2 in c:\users\ruchi\anaconda3\lib\site-packages (from selenium) (0.12.2)
# Requirement already satisfied: certifi>=2025.6.15 in c:\users\ruchi\anaconda3\lib\site-packages (from selenium) (2025.8.3)
# Requirement already satisfied: typing_extensions~=4.14.0 in c:\users\ruchi\anaconda3\lib\site-packages (from selenium) (4.14.1)
# Requirement already satisfied: websocket-client~=1.8.0 in c:\users\ruchi\anaconda3\lib\site-packages (from selenium) (1.8.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ruchi\anaconda3\lib\site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\ruchi\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ruchi\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ruchi\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ruchi\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\ruchi\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\ruchi\anaconda3\lib\site-packages (from trio~=0.30.0->selenium) (25.3.0)
# Requirement already satisfied: sortedcontainers in c:\users\ruchi\anaconda3\lib\site-packages (from trio~=0.30.0->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\ruchi\anaconda3\lib\site-packages (from trio~=0.30.0->selenium) (3.7)
# Requirement already satisfied: outcome in c:\users\ruchi\anaconda3\lib\site-packages (from trio~=0.30.0->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\ruchi\anaconda3\lib\site-packages (from trio~=0.30.0->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\ruchi\anaconda3\lib\site-packages (from trio~=0.30.0->selenium) (1.17.1)
# Requirement already satisfied: wsproto>=0.14 in c:\users\ruchi\anaconda3\lib\site-packages (from trio-websocket~=0.12.2->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\ruchi\anaconda3\lib\site-packages (from urllib3[socks]~=2.5.0->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\ruchi\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.30.0->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\ruchi\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.12.2->selenium) (0.14.0)

# %%
# URLs for both pages
urls = [
    "https://www2.hm.com/de_de/damen/produkte/jeans.html",
    "https://www2.hm.com/de_de/damen/produkte/jeans.html?page=2",
    "https://www2.hm.com/de_de/herren/produkte/jeans.html",
    "https://www2.hm.com/de_de/herren/produkte/jeans.html?page=2",
    "https://www2.hm.com/de_de/kinder/9-14j/kleidung/jeans.html"
]

all_products = []

# Step 1: Scrape both pages
for url in urls:
    if "damen" in url:
        gender = "Women"
    elif "herren" in url:
        gender = "Men"
    elif "kinder" in url:
        gender = "Kid"
    else:
        gender = "Unknown"
    
    driver = webdriver.Chrome()
    driver.get(url)

    body = driver.find_element(By.TAG_NAME, "body")
    for _ in range(10):
        body.send_keys(Keys.END)
        time.sleep(2)

    soup = BeautifulSoup(driver.page_source, "html.parser")
    driver.quit()

    grid = soup.find("ul", attrs={"data-elid": "product-grid"})
    if grid:
        products = grid.find_all("article")
        for p in products:
            all_products.append((p, gender))

print(f"✅ Total scraped: {len(all_products)} products")
# Out:
# ✅ Total scraped: 180 products

# %%
FALLBACK_COLOR_NAMES = [
    'BLACK', 'WHITE', 'RED', 'GREEN', 'BLUE', 'YELLOW', 'CYAN', 'MAGENTA',
    'GRAY', 'ORANGE', 'PURPLE', 'PINK', 'BROWN', 'NAVY', 'MAROON',
    'OLIVE', 'TEAL', 'LIME', 'SILVER', 'AQUA', 'FUCHSIA', 'GOLD', 'BEIGE'
]

COLOR_CORRECTIONS = {
    'SLATEGRAY': 'GRAY',
    'LIGHTGRAY': 'GRAY',
    'DARKGRAY': 'GRAY',
    'PEACHPUFF': 'BROWN',
    'LAVENDER': 'BROWN',
    'TEAL': 'BLUE',
    'SILVER': 'BLUE',
    'INDIGO': 'BLUE',
    'DARKGREEN': 'BLUE',
    'BEIGE': 'WHITE',
    'UNKNOWN': 'BLUE',
    'MAROON':'RED'
}

def closest_color(rgb_tuple):
    min_distance = float('inf')
    closest_name = None
    for name in FALLBACK_COLOR_NAMES:
        try:
            r_c, g_c, b_c = webcolors.name_to_rgb(name.lower())
            dist = (r_c - rgb_tuple[0])**2 + (g_c - rgb_tuple[1])**2 + (b_c - rgb_tuple[2])**2
            if dist < min_distance:
                min_distance = dist
                closest_name = name
        except:
            continue
    return closest_name or "BLUE"

def rgb_or_hex_to_name(color_code):
    try:
        if color_code.startswith("rgb"):
            rgb = tuple(map(int, re.findall(r'\d+', color_code)))
            return closest_color(rgb)
        elif color_code.startswith("#"):
            rgb = webcolors.hex_to_rgb(color_code)
            return closest_color(rgb)
    except:
        return "BLUE"
    return "BLUE"

# ----------- Step 4: Extraction Functions -----------
def jeans_des(product):
    try:
        return product.find("h2", class_="be6471 bf7846 d0e739").get_text(strip=True)
    except AttributeError:
        return "N/A"

def jeans_price(product):
    try:
        price = product.find("del")
        if price:
            return price.get_text(strip=True).replace("Normalpreis", "").strip()

        price = product.find("span", class_="b1cd4f b6e218")
        if price:
            return price.get_text(strip=True).strip()

        span_prices = product.find_all("span")
        for span in span_prices:
            if "€" in span.get_text():
                return span.get_text(strip=True).strip()

    except:
        pass

    return "N/A"

def jeans_colors(product):
    color_set = set()

    # 1. Named colors from title attribute (if available)
    for tag in product.select("a[title].c0d578"):
        raw = tag.get("title", "").strip().upper()
        color = COLOR_CORRECTIONS.get(raw, raw)
        color_set.add(color)

    # 2. Visual swatches from inline background-color
    for span in product.select("span.ea044e"):  # confirmed correct class
        style = span.get("style", "")
        match = re.search(r'background-color:\s*([^;]+)', style)
        if match:
            code = match.group(1).strip()
            raw = rgb_or_hex_to_name(code).upper()
            color = COLOR_CORRECTIONS.get(raw, raw)
            color_set.add(color)

    # 3. Fallback
    if not color_set:
        return [COLOR_CORRECTIONS.get("UNKNOWN", "BLUE")]

    return sorted(color_set)

# %%
data = []
for prod, gender in all_products:
    name = jeans_des(prod)
    price = jeans_price(prod)
    colors = jeans_colors(prod)

    if name != "N/A" and price != "N/A":
        formatted_colors = ", ".join([c.capitalize() for c in colors])
        data.append([name, price, formatted_colors, gender])
        print(f"🛍️ Name: {name}")
        print(f"💶 Price: {price}")
        print(f"🎨 Colors: {', '.join(colors)}")
        print(f"👕 Gender: {gender}")
        print("-" * 50)
# Out:
# 🛍️ Name: Wide High Ankle Jeans
# 💶 Price: 34,99 €
# 🎨 Colors: BLUE, BROWN, WHITE
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Wide High Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLACK, BLUE
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Wide High Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLACK, BLUE, GRAY
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Wide High Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLACK, BLUE
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Wide High Jeans
# 💶 Price: 34,99 €
# 🎨 Colors: BLACK, WHITE
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Wide High Ankle Jeans
# 💶 Price: 34,99 €
# 🎨 Colors: BLUE, BROWN
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Wide High Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLACK, BLUE, GRAY
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Skinny High Jeans
# 💶 Price: 24,99 €
# 🎨 Colors: BLACK, BLUE
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Slim Mom High Ankle Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLUE, GRAY
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Flared High Jeans
# 💶 Price: 24,99 €
# 🎨 Colors: BLUE, WHITE
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Wide High Jeans
# 💶 Price: 34,99 €
# 🎨 Colors: BLACK, WHITE
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Wide High Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLACK, BLUE, WHITE
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Flared High Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLUE, WHITE
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Wide High Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLACK, BLUE
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Wide Ultra High Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLACK, BLUE
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Slim Mom High Ankle Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLUE, GRAY
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Wide Ultra High Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLACK, BLUE
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Wide Ultra High Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLACK, BLUE
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Wide Regular Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLUE
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Slim Mom High Ankle Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLUE, GRAY
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Wide High Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLACK, BLUE
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Wide High Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLACK, BLUE
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Weite Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLACK, BLUE
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Flared High Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLUE, WHITE
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Wide Ultra High Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLACK, BLUE
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Wide High Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLACK, BLUE, RED
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Wide High Jeans
# 💶 Price: 34,99 €
# 🎨 Colors: BLACK, WHITE
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Skinny High Jeans
# 💶 Price: 24,99 €
# 🎨 Colors: BLACK, BLUE
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Flared Low Jeans
# 💶 Price: 22,99 €
# 🎨 Colors: BLACK, BLUE
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Flared Low Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLACK, GRAY
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Wide High Ankle Jeans
# 💶 Price: 34,99 €
# 🎨 Colors: BLUE, BROWN, WHITE
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Wide High Ankle Jeans
# 💶 Price: 34,99 €
# 🎨 Colors: BLUE, BROWN, WHITE
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Wide High Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLACK, BLUE, GRAY
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Wide High Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLACK, BLUE, RED
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Wide High Ankle Jeans
# 💶 Price: 34,99 €
# 🎨 Colors: BLACK, BLUE, BROWN
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Flared High Jeans
# 💶 Price: 19,99 €
# 🎨 Colors: GRAY, WHITE
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Weite Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLACK, BLUE
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Wide High Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLACK, BLUE, GRAY
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Wide High Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLACK, BLUE, RED
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Straight High Jeans
# 💶 Price: 39,99 €
# 🎨 Colors: GRAY
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Weite Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLACK, BLUE
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Wide High Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLACK, BLUE, GRAY
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Weite Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLACK, BLUE, WHITE
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Weite Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLACK, BLUE
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Wide Ultra High Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLUE, WHITE
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Wide High Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLACK, BLUE, RED
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Barrel High Jeans
# 💶 Price: 39,99 €
# 🎨 Colors: BLACK, GRAY
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Slim Straight High Ankle Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLUE, GRAY
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Wide High Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLACK, BLUE, WHITE
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Skinny Regular Ankle Jeans
# 💶 Price: 39,99 €
# 🎨 Colors: BLACK, GRAY
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Wide Ultra High Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLACK, BLUE
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Denimhose mit Kordelzug
# 💶 Price: 24,99 €
# 🎨 Colors: BLACK, BLUE
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Wide High Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLACK, BLUE
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: True To You Skinny Ultra High Ankle Jeans
# 💶 Price: 49,99 €
# 🎨 Colors: BLUE
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Denimhose mit Kordelzug
# 💶 Price: 24,99 €
# 🎨 Colors: BLACK, BLUE
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Slim Mom High Ankle Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLACK, BLUE
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Flared Low Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLACK, GRAY
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Flared High Jeans
# 💶 Price: 19,99 €
# 🎨 Colors: GRAY, WHITE
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Wide High Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLACK, BLUE
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Barrel High Jeans
# 💶 Price: 39,99 €
# 🎨 Colors: BLACK, GRAY
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Wide Ultra High Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLUE, WHITE
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Barrel High Jeans
# 💶 Price: 39,99 €
# 🎨 Colors: BLACK, GRAY
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Denimhose mit Kordelzug
# 💶 Price: 24,99 €
# 🎨 Colors: BLACK, BLUE
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Wide High Jeans
# 💶 Price: 44,99 €
# 🎨 Colors: GRAY, WHITE
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Wide High Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLACK, BLUE, GRAY
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Straight High Jeans
# 💶 Price: 39,99 €
# 🎨 Colors: GRAY
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Flared Low Jeans
# 💶 Price: 22,99 €
# 🎨 Colors: BLACK, BLUE
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Flared High Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLUE
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Weite Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLACK, BLUE
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Wide Ultra High Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLACK, BLUE, GRAY
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Wide Ultra High Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLACK, BLUE, GRAY
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: MAMA Before & After Straight Low Ankle Jeans
# 💶 Price: 44,99 €
# 🎨 Colors: GRAY
# 👕 Gender: Women
# --------------------------------------------------
# 🛍️ Name: Straight Regular Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLACK, BLUE, GRAY
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Baggy Jeans
# 💶 Price: 39,99 €
# 🎨 Colors: BLUE, GRAY
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Relaxed Jeans
# 💶 Price: 34,99 €
# 🎨 Colors: BLACK, GRAY
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Straight Regular Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLACK, BLUE, GRAY
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Straight Regular Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLACK, BLUE, GRAY
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Loose Jeans
# 💶 Price: 39,99 €
# 🎨 Colors: BLACK, GRAY
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Baggy Jeans
# 💶 Price: 39,99 €
# 🎨 Colors: BLUE, GRAY
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Loose Jeans
# 💶 Price: 39,99 €
# 🎨 Colors: BLACK, GRAY
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Baggy Jeans
# 💶 Price: 39,99 €
# 🎨 Colors: BLUE, GRAY
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Regular Tapered Jeans
# 💶 Price: 39,99 €
# 🎨 Colors: BLACK, BLUE, GRAY
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Relaxed Jeans
# 💶 Price: 34,99 €
# 🎨 Colors: BLACK, GRAY
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Bootcut Regular Jeans
# 💶 Price: 49,99 €
# 🎨 Colors: BLACK, BLUE
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Regular Tapered Jeans
# 💶 Price: 39,99 €
# 🎨 Colors: BLACK, BLUE, GRAY
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Loose Jeans
# 💶 Price: 39,99 €
# 🎨 Colors: BLACK, GRAY
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Straight Regular Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLACK, BLUE
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Bootcut Regular Jeans
# 💶 Price: 49,99 €
# 🎨 Colors: BLACK, BLUE
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Relaxed Jeans
# 💶 Price: 39,99 €
# 🎨 Colors: BLACK, BLUE
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Loose Straight Jeans
# 💶 Price: 39,99 €
# 🎨 Colors: BLACK, GRAY
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Space Relaxed Straight Leg Jeans
# 💶 Price: 70,00 €
# 🎨 Colors: BLACK, BLUE, GRAY
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Orbit Mid Waist Regular Straight Leg Jeans
# 💶 Price: 59,00 €
# 🎨 Colors: BLUE, GRAY
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Baggy Jeans
# 💶 Price: 39,99 €
# 🎨 Colors: BLUE
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: MIST Wide Jeans
# 💶 Price: 129,00 €
# 🎨 Colors: BLACK, BLUE, GRAY
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Straight Loose Lightweight Jeans
# 💶 Price: 39,99 €
# 🎨 Colors: BLACK, BLUE
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Relaxed Jeans
# 💶 Price: 39,99 €
# 🎨 Colors: BLACK, GRAY
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Astro Loose Baggy Leg Jeans
# 💶 Price: 70,00 €
# 🎨 Colors: BLACK, BLUE, GRAY
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Regular Jeans
# 💶 Price: 39,99 €
# 🎨 Colors: BLACK, BLUE, GRAY
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Baggy Jeans
# 💶 Price: 39,99 €
# 🎨 Colors: BLACK
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Super Baggy Jeans
# 💶 Price: 44,99 €
# 🎨 Colors: BLACK, BLUE, GRAY
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Baggy Jeans
# 💶 Price: 39,99 €
# 🎨 Colors: BLACK
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Super Baggy Jeans
# 💶 Price: 39,99 €
# 🎨 Colors: BLACK, BLUE
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Loose Straight Jeans
# 💶 Price: 39,99 €
# 🎨 Colors: BLACK, GRAY
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Super Baggy Jeans
# 💶 Price: 44,99 €
# 🎨 Colors: BLACK, BLUE, GRAY
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Relaxed Jeans
# 💶 Price: 39,99 €
# 🎨 Colors: BLACK, BLUE
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Relaxed Jeans
# 💶 Price: 39,99 €
# 🎨 Colors: BLACK, BLUE
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Loose Straight Jeans
# 💶 Price: 39,99 €
# 🎨 Colors: BLACK, GRAY
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Relaxed Jeans
# 💶 Price: 39,99 €
# 🎨 Colors: BLACK, GRAY
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Slim Jeans
# 💶 Price: 39,99 €
# 🎨 Colors: GRAY
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: RIDER JEANS MIT GERADEM BEIN
# 💶 Price: 99,00 €
# 🎨 Colors: BLACK, GRAY, WHITE
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: CASK JEANS MIT BARREL-BEIN
# 💶 Price: 99,00 €
# 🎨 Colors: BLUE
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Super Baggy Jeans
# 💶 Price: 44,99 €
# 🎨 Colors: BLACK, BLUE, GRAY
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Loose Straight Jeans
# 💶 Price: 39,99 €
# 🎨 Colors: BLACK, BLUE
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Straight Loose Lightweight Jeans
# 💶 Price: 39,99 €
# 🎨 Colors: BLACK, BLUE
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Loose Straight High Jeans
# 💶 Price: 39,99 €
# 🎨 Colors: GRAY, WHITE
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: PIER JEANS MIT SCHMALEM BEIN
# 💶 Price: 79,00 €
# 🎨 Colors: BLUE
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Slim Jeans
# 💶 Price: 39,99 €
# 🎨 Colors: GRAY
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Straight Loose Lightweight Jeans
# 💶 Price: 39,99 €
# 🎨 Colors: BLACK, BLUE
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Astro Loose Baggy Leg Jeans
# 💶 Price: 70,00 €
# 🎨 Colors: BLACK, BLUE, GRAY
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Galaxy Loose Straight Leg Jeans
# 💶 Price: 60,00 €
# 🎨 Colors: BLACK, BLUE
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: MIST Wide Jeans
# 💶 Price: 129,00 €
# 🎨 Colors: BLACK, BLUE, GRAY
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Barrel Loose Jeans
# 💶 Price: 44,99 €
# 🎨 Colors: BLACK, BLUE
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Straight Loose Jeans
# 💶 Price: 39,99 €
# 🎨 Colors: BLUE, BROWN, GRAY
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: OCEAN Loose Straight Jeans
# 💶 Price: 89,00 €
# 🎨 Colors: BLUE, GRAY
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Space Relaxed Straight Leg Jeans
# 💶 Price: 70,00 €
# 🎨 Colors: BLACK, BLUE, GRAY
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Loose Fit Jeans
# 💶 Price: 39,99 €
# 🎨 Colors: BLUE, GRAY
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Astro Loose Baggy Leg Jeans
# 💶 Price: 70,00 €
# 🎨 Colors: BLACK, BLUE, GRAY
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Loose Fit Jeans
# 💶 Price: 39,99 €
# 🎨 Colors: BLUE, GRAY
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Space Relaxed Straight Leg Jeans
# 💶 Price: 70,00 €
# 🎨 Colors: BLACK, BLUE, GRAY
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Orbit Mid Waist Regular Straight Leg Jeans
# 💶 Price: 59,00 €
# 🎨 Colors: BLUE, GRAY
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: SIGNATURE JEANS MIT GERADEM BEIN
# 💶 Price: 89,00 €
# 🎨 Colors: BLACK, BLUE, GRAY
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: RIDER RAW SELVEDGE-JEANS MIT GERADEM BEIN
# 💶 Price: 129,00 €
# 🎨 Colors: BLUE
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: CANYON Bootcut-Jeans mit normaler Passform
# 💶 Price: 99,00 €
# 🎨 Colors: BLUE
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Straight Loose Jeans
# 💶 Price: 39,99 €
# 🎨 Colors: BLUE, BROWN, GRAY
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Space Relaxed Straight Leg Jeans
# 💶 Price: 70,00 €
# 🎨 Colors: BLACK, GRAY
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Space Relaxed Straight Leg Jeans
# 💶 Price: 70,00 €
# 🎨 Colors: BLACK, GRAY
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Ray Relaxed Tapered Leg Jeans
# 💶 Price: 60,00 €
# 🎨 Colors: BLACK, BLUE
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Galaxy Loose Straight Leg Jeans
# 💶 Price: 60,00 €
# 🎨 Colors: BLACK, BLUE
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Klean Regular Straight Leg Jeans
# 💶 Price: 70,00 €
# 🎨 Colors: BLACK
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: SIGNATURE JEANS MIT GERADEM BEIN
# 💶 Price: 89,00 €
# 🎨 Colors: BLACK, BLUE, GRAY
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: RIDER JEANS MIT GERADEM BEIN
# 💶 Price: 99,00 €
# 🎨 Colors: BLACK, GRAY, WHITE
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Loose Straight High Jeans
# 💶 Price: 39,99 €
# 🎨 Colors: GRAY, WHITE
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Space Relaxed Straight Leg Jeans
# 💶 Price: 70,00 €
# 🎨 Colors: BLACK, GRAY
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Mercury Relaxed Bootcut Leg Jeans
# 💶 Price: 60,00 €
# 🎨 Colors: BLACK, BLUE, GRAY
# 👕 Gender: Men
# --------------------------------------------------
# 🛍️ Name: Baggy Fit Cargo Jeans
# 💶 Price: 34,99 €
# 🎨 Colors: BLUE
# 👕 Gender: Kid
# --------------------------------------------------
# 🛍️ Name: Baggy Fit Low Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLUE
# 👕 Gender: Kid
# --------------------------------------------------
# 🛍️ Name: Baggy Fit Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLACK, BLUE, GRAY
# 👕 Gender: Kid
# --------------------------------------------------
# 🛍️ Name: Bootcut Leg Low Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLACK, BLUE
# 👕 Gender: Kid
# --------------------------------------------------
# 🛍️ Name: Super Baggy Jeans
# 💶 Price: 34,99 €
# 🎨 Colors: BLUE, GRAY
# 👕 Gender: Kid
# --------------------------------------------------
# 🛍️ Name: Baggy Fit Bootcut Leg Jeans
# 💶 Price: 27,99 €
# 🎨 Colors: BLACK, BLUE
# 👕 Gender: Kid
# --------------------------------------------------
# 🛍️ Name: Comfort Stretch Slim Fit Jeans
# 💶 Price: 24,99 €
# 🎨 Colors: BLUE, GRAY
# 👕 Gender: Kid
# --------------------------------------------------
# 🛍️ Name: Baggy Fit Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLUE, GRAY
# 👕 Gender: Kid
# --------------------------------------------------
# 🛍️ Name: Baggy Fit Bootcut Leg Jeans
# 💶 Price: 34,99 €
# 🎨 Colors: BLUE
# 👕 Gender: Kid
# --------------------------------------------------
# 🛍️ Name: Wide Leg Jeans
# 💶 Price: 24,99 €
# 🎨 Colors: BLACK, BLUE, GRAY
# 👕 Gender: Kid
# --------------------------------------------------
# 🛍️ Name: Loose Fit Jeans
# 💶 Price: 24,99 €
# 🎨 Colors: BLACK, BLUE
# 👕 Gender: Kid
# --------------------------------------------------
# 🛍️ Name: Wide Leg Jeans
# 💶 Price: 24,99 €
# 🎨 Colors: BLACK, BLUE, GRAY
# 👕 Gender: Kid
# --------------------------------------------------
# 🛍️ Name: Loose Fit Jeans
# 💶 Price: 24,99 €
# 🎨 Colors: BLACK, BLUE
# 👕 Gender: Kid
# --------------------------------------------------
# 🛍️ Name: Relaxed Tapered Fit Jeans
# 💶 Price: 24,99 €
# 🎨 Colors: BLACK, BLUE, GRAY
# 👕 Gender: Kid
# --------------------------------------------------
# 🛍️ Name: Baggy Fit Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLACK, BLUE, GRAY
# 👕 Gender: Kid
# --------------------------------------------------
# 🛍️ Name: Baggy Fit Bootcut Leg Jeans
# 💶 Price: 27,99 €
# 🎨 Colors: BLACK, BLUE
# 👕 Gender: Kid
# --------------------------------------------------
# 🛍️ Name: Straight Leg Jeans
# 💶 Price: 27,99 €
# 🎨 Colors: BLUE
# 👕 Gender: Kid
# --------------------------------------------------
# 🛍️ Name: Baggy Fit Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLACK, BLUE, GRAY
# 👕 Gender: Kid
# --------------------------------------------------
# 🛍️ Name: Loose Fit Jeans
# 💶 Price: 24,99 €
# 🎨 Colors: BLACK, BLUE
# 👕 Gender: Kid
# --------------------------------------------------
# 🛍️ Name: 2er-Pack Comfort Stretch Relaxed Fit Jeans
# 💶 Price: 49,99 €
# 🎨 Colors: BLACK, BLUE, GRAY
# 👕 Gender: Kid
# --------------------------------------------------
# 🛍️ Name: Flared Leg Low Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLUE, GRAY
# 👕 Gender: Kid
# --------------------------------------------------
# 🛍️ Name: Bootcut Leg Low Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLACK, BLUE
# 👕 Gender: Kid
# --------------------------------------------------
# 🛍️ Name: Wide Leg Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLACK, BLUE
# 👕 Gender: Kid
# --------------------------------------------------
# 🛍️ Name: Wide Leg Jeans
# 💶 Price: 24,99 €
# 🎨 Colors: BLACK, BLUE, GRAY
# 👕 Gender: Kid
# --------------------------------------------------
# 🛍️ Name: Flared Leg Low Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLUE, GRAY
# 👕 Gender: Kid
# --------------------------------------------------
# 🛍️ Name: Super Baggy Jeans
# 💶 Price: 34,99 €
# 🎨 Colors: BLUE, GRAY
# 👕 Gender: Kid
# --------------------------------------------------
# 🛍️ Name: Loose Fit Jeans
# 💶 Price: 39,99 €
# 🎨 Colors: BLUE
# 👕 Gender: Kid
# --------------------------------------------------
# 🛍️ Name: Baggy Fit Bootcut Leg Jeans
# 💶 Price: 34,99 €
# 🎨 Colors: BLUE
# 👕 Gender: Kid
# --------------------------------------------------
# 🛍️ Name: Slim Fit Jeans mit Biesen
# 💶 Price: 29,99 €
# 🎨 Colors: BLUE
# 👕 Gender: Kid
# --------------------------------------------------
# 🛍️ Name: Super Baggy Jeans
# 💶 Price: 34,99 €
# 🎨 Colors: BLUE, GRAY
# 👕 Gender: Kid
# --------------------------------------------------
# 🛍️ Name: Wide Leg Cargo Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLUE, GRAY
# 👕 Gender: Kid
# --------------------------------------------------
# 🛍️ Name: Loose Fit Wide Leg Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLUE
# 👕 Gender: Kid
# --------------------------------------------------
# 🛍️ Name: Wide Leg Cargo Jeans
# 💶 Price: 29,99 €
# 🎨 Colors: BLUE, GRAY
# 👕 Gender: Kid
# --------------------------------------------------
# 🛍️ Name: Baggy Fit Carpenter Jeans
# 💶 Price: 34,99 €
# 🎨 Colors: BLACK, BLUE
# 👕 Gender: Kid
# --------------------------------------------------
# 🛍️ Name: Baggy Fit Bootcut Leg Jeans
# 💶 Price: 34,99 €
# 🎨 Colors: BLUE
# 👕 Gender: Kid
# --------------------------------------------------
# 🛍️ Name: Jeans mit weitem Bein
# 💶 Price: 29,99 €
# 🎨 Colors: BLUE, GRAY
# 👕 Gender: Kid
# --------------------------------------------------

# %%
columns = ["Name", "Price", "Colors", "Gender"]
df = pd.DataFrame(data, columns=columns)
df.to_csv("hm_jeans_with_colors.csv", index=False, encoding="utf-8")
print(f"✅ CSV saved with {len(all_products)} entries")
# Out:
# ✅ CSV saved with 180 entries

# %%
formatted_colors = ", ".join([c.capitalize() for c in colors])
data.append([name, price, formatted_colors, gender])

# %%
columns = ["Name", "Price", "Colors", "Gender"]
df = pd.DataFrame(data, columns=columns)
df["Company"] = "H&M"  # Add constant column after df is created
df
# Out:
#                             Name    Price              Colors Gender Company
# 0          Wide High Ankle Jeans  34,99 €  Blue, Brown, White  Women     H&M
# 1                Wide High Jeans  29,99 €         Black, Blue  Women     H&M
# 2                Wide High Jeans  29,99 €   Black, Blue, Gray  Women     H&M
# 3                Wide High Jeans  29,99 €         Black, Blue  Women     H&M
# 4                Wide High Jeans  34,99 €        Black, White  Women     H&M
# ..                           ...      ...                 ...    ...     ...
# 176         Wide Leg Cargo Jeans  29,99 €          Blue, Gray    Kid     H&M
# 177    Baggy Fit Carpenter Jeans  34,99 €         Black, Blue    Kid     H&M
# 178  Baggy Fit Bootcut Leg Jeans  34,99 €                Blue    Kid     H&M
# 179        Jeans mit weitem Bein  29,99 €          Blue, Gray    Kid     H&M
# 180        Jeans mit weitem Bein  29,99 €          Blue, Gray    Kid     H&M
#
# [181 rows x 5 columns]
